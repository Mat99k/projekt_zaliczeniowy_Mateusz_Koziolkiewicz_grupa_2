# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import spacy

# %%
# !pip install spacy -U
# !python -m spacy download pl_core_news_sm

# %%
nlp = spacy.load("pl_core_news_sm")

# %%
MAIN_DATA = pd.read_csv("/content/lgbt.csv")

# %%
df = MAIN_DATA.copy()

# %% [markdown]
# Część 1 - przetwarzanie i czyszczenie danych

# %% [markdown]
# 1. Zamień skróty nazw dni tygodnia na polskie odpowiedniki (pełne nazwy dni tygodnia) - kolumna created_at

# %%
df['created_at'] = df['created_at'].replace(regex={"Mon": "Poniedziałek", "Tue": "Wtorek", "Wed": "Środa", "Thu": "Czwartek", "Fri": "Piątek", "Sat": "Sobota", "Sun": "Niedziela"})

# %%
df

# %% [markdown]
# 2. Zamień skróty nazw miesięcy na liczbowe odpowiedniki (np Jun na 06) - kolumna user_created_at

# %%
df['user_created_at'] = df['user_created_at'].replace(regex={"Jan" : "01", "Feb" : "02", "Mar" : "03", "Apr" : "04", "May" : "05", "Jun" : "06",	"Jul" : "07",	"Aug" : "08",	"Sep" : "09",	"Oct" : "10", "Nov" : "11",	"Dec" : "12"})

# %%
df

# %% [markdown]
# 3. Pobierz wszystkie linki do tweetów i przekaż je do listy.

# %%
print(df['tweet_url'].values.tolist())
# Out:
# ['https://twitter.com/SBrycki/status/1387811273010712577', 'https://twitter.com/Biezrzad/status/1387797982557392911', 'https://twitter.com/komuszyca/status/1387797356050063368', 'https://twitter.com/LocusSolusToJa/status/1387800529947013121', 'https://twitter.com/radekdragon1973/status/1387796227706720256', 'https://twitter.com/MoSadkowska/status/1387804828315828235', 'https://twitter.com/EmilAron9999/status/1387812459063431199', 'https://twitter.com/KRESYPL/status/1387801252592033793', 'https://twitter.com/enzaismoki/status/1387800027154767872', 'https://twitter.com/IZABELA38007905/status/1387802848109514755', 'https://twitter.com/qurk155/status/1387811363003768833', 'https://twitter.com/Movsd6/status/1387800194104823809', 'https://twitter.com/jbart_xy/status/1387812520426196993', 'https://twitter.com/TomaszBuczynski/status/1387794661641789441', 'https://twitter.com/CherryTechTips/status/1387799002733813760', 'https://twitter.com/Bronek53609552/status/1387811160410529803', 'https://twitter.com/AdahoPi/status/1387791236686286853', 'https://twitter.com/MrusPani/status/1387797165737709570', 'https://twitter.com/s_wodzynski/status/1387799684517928968', 'https://twitter.com/joldud1961/status/1387811213782958086', 'https://twitter.com/MartinSwidersky/status/1387808689332051977', 'https://twitter.com/Alex_H_Hampton/status/1387795380155437056', 'https://twitter.com/ilintar/status/1387806648056655879', 'https://twitter.com/DanAlvarezz/status/1387792134988836867', 'https://twitter.com/MalgoPiet/status/1387805505104515072', 'https://twitter.com/Andrzej78752085/status/1387809563274002433', 'https://twitter.com/46Cochise/status/1387804669532049409', 'https://twitter.com/unijnakapusta60/status/1387794191284113410', 'https://twitter.com/hubal63/status/1387796816524161027', 'https://twitter.com/janczewski_p/status/1387795197900296193', 'https://twitter.com/LeszekDabrowa/status/1387813126310088704', 'https://twitter.com/NHLwPL/status/1387792775266119682', 'https://twitter.com/Aleks_LeksaN/status/1387809276681457671', 'https://twitter.com/JuliaGlowin/status/1387794337250037760', 'https://twitter.com/Ala9025/status/1387810516756750346', 'https://twitter.com/LublinNarodowy/
# %%
def remove_stopwords(tekst):
  doc = nlp(tekst)
  result = ""
  for token in doc:
    if token.is_stop == False:
      result += token.text + " "
  return result

# %%
df["text_without_stopwords"] = df["text"].apply(remove_stopwords)

# %% [markdown]
# Część 2 - eksploracyjna analiza danych

# %% [markdown]
# 1. Wypisz top5 tweetów z największa liczbą polubień.

# %%
df = df.sort_values('favorite_count', ascending = False) 
df[['favorite_count', 'text']][0:5]
# Out:
#       favorite_count                                               text
# 9462            1818  Piłkarska Federacja Wysp Owczych wprowadziła z...
# 4014            1685  Lewica zawarła sojusz z:\n- „LGBT to ideologia...
# 4052            1447  To jest niesamowite, jak niektórym się przypom...
# 3790            1360  Hura! Wygrali prawie wszyscy. PiS, bo nie ma k...
# 8835            1203  Serdeczne życzenia urodzinowe dla Moniki Rosy ...

# %% [markdown]
# 2. Wypisz top5 tweetów z największa liczbą retweetów.

# %%
df = df.sort_values('retweet_count', ascending = False) 
df[['retweet_count', 'text']][0:5]
# Out:
#       retweet_count                                               text
# 3654           2061  A nie dałoby się tak w Polsce: osoby lgbt mogł...
# 8167           1323  Dziś PRAWDA o #MarszRówności #LGBT. \nProszę o...
# 34             1031  Znów w UE oskarżają Polskę o „gorszą kulturę”....
# 3249           1031  Znów w UE oskarżają Polskę o „gorszą kulturę”....
# 146            1031  Znów w UE oskarżają Polskę o „gorszą kulturę”....

# %% [markdown]
# 3. Wyświetl tylko te tweety, które nie są uznane jako “wrażliwe” (kolumna possibly_sensitive).

# %%
index = np.where((df['possibly_sensitive'] != True) )
df.loc[index]
# Out:
#        coordinates  ...                             text_without_stopwords
# 0              NaN  ...  ostatniej chwili 🏳 ️‍ 🌈 Kraśnik szóstym miaste...
# 1              NaN  ...  1,5 MLD EURO WSPIERANIE LGBT ! \n . \n\n https...
# 2              NaN  ...  ostatniej chwili 🏳 ️‍ 🌈 Kraśnik szóstym miaste...
# 3              NaN  ...  @filippskora stosujemy podwójnych standardów ....
# 4              NaN  ...  Uchwała strefie wolnej LGBT Kraśniku UCHYLONA ...
# ...            ...  ...                                                ...
# 12151          NaN  ...  Szwecji , migranci gwałcą białe kobiety , migr...
# 12152          NaN  ...  Szwedzki działacz lgbt , ekspert bezpiecznego ...
# 12153          NaN  ...              @PolsatNewsPL typowy działacz LGBT .
# 12154          NaN  ...  - Sąd przeciwstawił próbie zakneblowania pozwa...
# 12155          NaN  ...  Szwedzki działacz lgbt , ekspert bezpiecznego ...
#
# [12086 rows x 36 columns]

# %% [markdown]
# 4. Wyświetl tweety użytkownika, który założył konto najwcześniej (spośród wszystkich użytkowników w datasecie) (kolumna user_created_at).

# %%
df.loc[df['user_created_at'] == df['user_created_at'].max()]
# Out:
#        coordinates  ...                             text_without_stopwords
# 10141          NaN  ...  Niedziele handlu wprowadzili interesie Kościoł...
# 6360           NaN  ...  Pawłowska słyszała słów " LGBT ideologia , lud...
#
# [2 rows x 36 columns]

# %% [markdown]
# 5. Wyświetl tweety użytkownika. który ma najwięcej followersów.

# %%
df = df.sort_values('user_followers_count', ascending = False) 
df[['user_followers_count', 'user_name']][0:1]
# Out:
#      user_followers_count user_name
# 244               1531620     tvn24

# %% [markdown]
# 6. Wyświetl tylko zweryfikowanych użytkowników (kolumna user_verified)

# %%
index = np.where((df['user_verified'] == True) )
df.loc[index]
# Out:
#        coordinates  ...                             text_without_stopwords
# 49             NaN  ...  Presja popłaca ! \n\n Radni Kraśnika uchylili ...
# 195            NaN  ...  Kolejny spadamy . Ranking @freedomhouse wymien...
# 244            NaN  ...  Radni Kraśnika zmienili zdanie sami uchylili u...
# 317            NaN  ...  # Kraśnik : Rada Miasta uchyliła przyjęte 2019...
# 432            NaN  ...  Radni Kraśnika uchylili uchwałę anty - LGBT ht...
# 434            NaN  ...  ‼️Dania pozwie polski rząd ? „ Konserwatyści p...
# 500            NaN  ...  ‼️Dania pozwie polski rząd ? „ Konserwatyści p...
# 532            NaN  ...  Radni Kraśnika uchylili uchwałę anty - LGBT ht...
# 601            NaN  ...  [ Treść PREMIUM ] | " Ogromna liczba osób LGBT...
# 755            NaN  ...  Kraśnik odrzucił uchwałę " przeciw ideologii L...
# 929            NaN  ...  Bezdomne osoby LGBT szukają akceptacji schroni...
# 933            NaN  ...  Bezdomne osoby LGBT szukają akceptacji schroni...
# 952            NaN  ...  Bezdomne osoby LGBT szukają akceptacji schroni...
# 1443           NaN  ...  Nagonka LGBT , tępa propaganda , marnowanie pu...
# 1454           NaN  ...  Nagonka LGBT , tępa propaganda , marnowanie pu...
# 1537           NaN  ...  Nagonka LGBT , tępa propaganda , marnowanie pu...
# 1947           NaN  ...  Pawłowska wywiadzie powiedziała , „ zna ” słów...
# 2104           NaN  ...  alternatywą , Polski trafią środki UE , . traf...
# 2126           NaN  ...  Lewica zawarła sojusz : \n - „ LGBT ideologia ...
# 2226           NaN  ...  alternatywą , Polski trafią środki UE , . traf...
# 2630           NaN  ...  [ TVN24 ] Pawłowska : głosowałam Dudę . ocenia...
# 2648           NaN  ...  " LGBT ideologia , ludzie ! " - prezydentowi u...
# 2651           NaN  ...  [ TVN24 ] Pawłowska : głosowałam Dudę . ocenia...
# 2655           NaN  ...  [ TVN24 ] Pawłowska : głosowałam Dudę . ocenia...
# 2671           NaN  ...  [ TVN24 ] Pawłowska : głosowałam Dudę . ocenia...
# 2775           NaN  ...  Najwyższy czas , Watykan przestał tyle mówić s...
# 2985           NaN  ...  przynajmniej wiadomo p . posłanka @Pawlowska_p...
# 4014           NaN  ...  Lewica zawarła sojusz : \n - „ LGBT ideologia ...
# 4480           NaN  ...  75 . mieszkań strefach wolnych # LGBT . https:...
# 4608           NaN  ...  🇵 🇱 @SolidarnaPL konsekwentnie stoimy straży p...
# 4796           NaN  ...  Hej @Lewica - osoby LGBT wciąż prześladowane ,...
# 5142           NaN  ...  polityce znać jednej najgłośniejszych wypowied...
# 5947           NaN  ...  " Uważam , poruszanie tematu osób LGBT kampani...
# 7104           NaN  ...  " NYT " : Ludzie LGBT   wyjeżdżają Polski . " ...
# 8159           NaN  ...  najintymniejszych rozmów cyku # PerlageStories...
# 8561           NaN  ...  Serdeczne życzenia urodzinowe Moniki Rosy - po...
# 8795           NaN  ...  HOMOFOB KANDYDATEM PREZESA IPN ❗ \n\n 💬 " Osob...
# 8835           NaN  ...  Serdeczne życzenia urodzinowe Moniki Rosy - po...
# 8895           NaN  ...  " La Repubblica " pisze Polsce : LGBT , zakaz ...
# 9412           NaN  ...  Zakaz okazywania wsparcia osobom LGBT . Czerwo...
# 9568           NaN  ...  Protest LGBT BLM Nowym Jorku . Zdewastowano hi...
# 9851           NaN  ...  Wójt gminy Grunwald pisze list premiera Mateus...
# 10259          NaN  ...  Działacz LGBT skazany gwałty migrantach . orga...
# 10516          NaN  ...  - Sukces @OrdoIuris . Pozew organizacji LGBT w...
# 11132          NaN  ...  mojej zgody dezinformację strony KE sprawie rz...
#
# [45 rows x 36 columns]

# %% [markdown]
# 7. Podaj, w który dzień tygodnia najczęściej były publikowane tweety z datasetu

# %%
df_copy = pd.DataFrame()

df_copy['published_day'] = df['created_at'].str.split(" ").str[0]

print("Dzień:", df_copy['published_day'].value_counts().idxmax())
# Out:
# Dzień: Środa

# %% [markdown]
# Część 3 - przetwarzanie języka naturalnego

# %% [markdown]
# 1. Rozpoznaj osoby (persName) i przekaż je do kolumny o nazwie persons

# %%
doc = [nlp(x) for x in df["text"]]

lista_osoby = []
for tweet in doc:
  osoby = ""
  for keyword in tweet.ents:
    if keyword.label_ == "persName":
      osoby = osoby + keyword.text + ', '
  lista_osoby.append(osoby)

assert len(lista_osoby) == df.shape[0]
df["persons"] = lista_osoby

# %% [markdown]
# 2. Rozpoznaj miejsca (placeName) i przekaż je do kolumny o nazwie places

# %%
doc = [nlp(x) for x in df["text"]]

lista_miejsca = []
for tweet in doc:
  osoby = ""
  for keyword in tweet.ents:
    if keyword.label_ == "placeName":
      osoby = osoby + keyword.text + ', '
  lista_miejsca.append(osoby)

assert len(lista_osoby) == df.shape[0]
df["places"] = lista_miejsca

# %% [markdown]
# 3. Rozpoznaj organizacje (orgName) i przekaż je do kolumny o nazwie organizations

# %%
doc = [nlp(x) for x in df["text"]]

lista_organizacji = []
for tweet in doc:
  osoby = ""
  for keyword in tweet.ents:
    if keyword.label_ == "orgName":
      osoby = osoby + keyword.text + ', '
  lista_organizacji.append(osoby)

assert len(lista_osoby) == df.shape[0]
df["organizations"] = lista_organizacji

# %% [markdown]
# 4. Stwórz model, który rozpozna hashtagi w treści tweeta. Następnie przekaż je do kolumny o nazwie hashtags

# %%
nlp_blank = spacy.blank("pl")
ruler = nlp_blank.add_pipe("entity_ruler")

pattern = "\S+"
patterns = [{"label": "HASHTAG", "pattern": [{"ORTH": "#"}, {"TEXT": {"REGEX": pattern}}]}]

ruler.add_patterns(patterns)

def find_hashtag(tekst):
  doc = nlp_blank(tekst)
  result = ""
  for ent in doc.ents:
    if ent.label_ == "HASHTAG":
      result += ent.text + " "
  return result

df["hashtags"] = df["text"].apply(find_hashtag)

df

# %% [markdown]
# Część 4 - rozwiązywanie problemów/umiejętność interpretowania dokumentacji

# %% [markdown]
# 1. Wykorzystując pakiet matplotlib wykonaj wykres ilustrujący liczbę tweetów per dzień tygodnia

# %%
days = ["Poniedziałek", "Wtorek", "Środa", "Czwartek", "Piątek", "Sobota", "Niedziela"]

df_copy = df_copy.groupby(['published_day']).size().reindex(days) 


df_copy.plot(x=df_copy[0], y=df_copy[1], kind="bar")
